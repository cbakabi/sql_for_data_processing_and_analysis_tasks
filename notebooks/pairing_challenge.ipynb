# %%
# %load_ext sql

# %%
# %sql postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end LIMIT 5
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(0, 1956, 1, 'Elvis Presley', 'Elvis Presley', 'Heartbreak Hotel', 1.0),
#  (1, 1956, 2, 'Elvis Presley', 'Elvis Presley', "Don't Be Cruel", 2.0),
#  (2, 1956, 3, 'Nelson Riddle', 'Nelson Riddle', 'Lisbon Antigua', 3.0),
#  (3, 1956, 4, 'Platters', 'Platters', 'My Prayer', 4.0),
#  (4, 1956, 5, 'Gogi Grant', 'Gogi Grant', 'The Wayward Wind', 5.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE year = 1979 AND year_rank = 1
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# (psycopg2.errors.SyntaxError) syntax error at or near "FRO"
# LINE 1: SELECT * FRO billboard_top_100_year_end WHERE year = 1979 AN...
#                  ^
#
# [SQL: SELECT * FRO billboard_top_100_year_end WHERE year = 1979 AND year_rank = 1]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE artist = 'Fats Domino' ORDER BY year
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [(41, 1956, 41, 'Fats Domino', 'Fats Domino', 'Blueberry Hill', 42.0),
#  (25, 1956, 25, 'Fats Domino', 'Fats Domino', "I'm In Love Again", 26.0),
#  (94, 1956, 92, 'Fats Domino', 'Fats Domino', 'My Blue Heaven', 95.0),
#  (189, 1957, 87, 'Fats Domino', 'Fats Domino', 'Valley of Tears', 190.0),
#  (152, 1957, 50, 'Fats Domino', 'Fats Domino', 'Blue Monday', 153.0),
#  (150, 1957, 48, 'Fats Domino', 'Fats Domino', 'Blueberry Hill', 151.0),
#  (140, 1957, 38, 'Fats Domino', 'Fats Domino', "I'm Walkin'", 141.0),
#  (372, 1959, 68, 'Fats Domino', 'Fats Domino', 'I Want To Walk You Home', 373.0),
#  (478, 1960, 72, 'Fats Domino', 'Fats Domino', 'Walking To New Orleans', 479.0),
#  (589, 1961, 82, 'Fats Domino', 'Fats Domino', 'Let The Four Winds Blow', 590.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE artist = 'Mariah Carey' LIMIT 5
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(3502, 1990, 6, 'Mariah Carey', 'Mariah Carey', 'Vision Of Love', 3503.0),
#  (3574, 1990, 76, 'Mariah Carey', 'Mariah Carey', 'Love Takes Time', 3575.0),
#  (3611, 1991, 13, 'Mariah Carey', 'Mariah Carey', 'Someday', 3612.0),
#  (3621, 1991, 22, 'Mariah Carey', 'Mariah Carey', 'Emotions', 3622.0),
#  (3625, 1991, 26, 'Mariah Carey', 'Mariah Carey', "I Don't Wanna Cry", 3626.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end ORDER BY song_name ASC LIMIT 10
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [(6449, 2013, 81, 'Mariah Carey feat. Miguel', 'Miguel', '#Beautiful', 6450.0),
#  (6448, 2013, 81, 'Mariah Carey feat. Miguel', 'Mariah Carey', '#Beautiful', 6449.0),
#  (6469, 2013, 95, 'will.i.am feat. Justin Bieber', 'will.i.am', '#thatPOWER', 6470.0),
#  (6470, 2013, 95, 'will.i.am feat. Justin Bieber', 'Justin Bieber', '#thatPOWER', 6471.0),
#  (4994, 2003, 37, 'Jay-Z feat. Beyonce Knowles', 'Jay-Z', "'03 Bonnie And Clyde", 4995.0),
#  (4995, 2003, 37, 'Jay-Z feat. Beyonce Knowles', 'Beyonce Knowles', "'03 Bonnie And Clyde", 4996.0),
#  (2696, 1982, 39, 'Paul Davis', 'Paul Davis', "'65 Love Affair", 2697.0),
#  (4102, 1995, 88, 'After 7', 'After 7', "'Til You Do Me Right", 4103.0),
#  (323, 1959, 20, 'Everly Brothers', 'Everly Brothers', "('Til) I Kissed You", 324.0),
#  (3525, 1990, 27, 'Nelson', 'Nelson', "(Can't Live Without Your) Love And Affection", 3526.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE year = 1956 ORDER BY artist LIMIT 10
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [(71, 1956, 70, 'Al Hibbler', 'Al Hibbler', 'After the Lights Go Down Low', 72.0),
#  (49, 1956, 48, 'Ames Brothers', 'Ames Brothers', 'It Only Hurts For A Little While', 50.0),
#  (56, 1956, 55, 'Andy Williams', 'Andy Williams', 'Canadian Sunset', 57.0),
#  (21, 1956, 21, 'Bill Doggett', 'Bill Doggett', 'Honky Tonk', 22.0),
#  (33, 1956, 33, 'Bill Haley and His Comets', 'Bill Haley and His Comets', 'See You Later Alligator', 34.0),
#  (44, 1956, 44, 'Bing Crosby and Grace Kelly', 'Bing Crosby', 'True Love', 45.0),
#  (102, 1956, 100, 'Blue Stars', 'Blue Stars', 'Lullaby of Birdland', 103.0),
#  (30, 1956, 30, 'Buchanan and Goodman', 'Buchanan and Goodman', 'The Flying Saucer', 31.0),
#  (91, 1956, 89, 'Cadillacs', 'Cadillacs', 'Speedoo', 92.0),
#  (18, 1956, 18, 'Carl Perkins', 'Carl Perkins', 'Blue Suede Shoes', 19.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE artist = 'Elvis Presley' ORDER BY year DESC LIMIT 1
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 1 rows affected.
# [(2197, 1977, 64, 'Elvis Presley', 'Elvis Presley', 'Way Down', 2198.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE year BETWEEN 1970 AND 1980 AND year_rank = 1
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 11 rows affected.
# [(1417, 1970, 1, 'Simon and Garfunkel', 'Simon and Garfunkel', 'Bridge Over Troubled Water', 1418.0),
#  (1517, 1971, 1, 'Three Dog Night', 'Three Dog Night', 'Joy To The World', 1518.0),
#  (1617, 1972, 1, 'Roberta Flack', 'Roberta Flack', 'The First Time Ever I Saw Your Face', 1618.0),
#  (1719, 1973, 1, 'Tony Orlando and Dawn', 'Tony Orlando and Dawn', "Tie A Yellow Ribbon 'Round The Ole Oak Tree", 1720.0),
#  (1822, 1974, 1, 'Barbra Streisand', 'Barbra Streisand', 'The Way We Were', 1823.0),
#  (1926, 1975, 1, 'Captain and Tennille', 'Captain and Tennille', 'Love Will Keep Us Together', 1927.0),
#  (2028, 1976, 1, 'Wings', 'Wings', 'Silly Love Songs', 2029.0),
#  (2132, 1977, 1, 'Rod Stewart', 'Rod Stewart', "Tonight's The Night (Gonna Be Alright)", 2133.0),
#  (2234, 1978, 1, 'Andy Gibb', 'Andy Gibb', 'Shadow Dancing', 2235.0),
#  (2338, 1979, 1, 'Knack', 'Knack', 'My Sharona', 2339.0),
# ...

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE group_name LIKE '%feat.%' LIMIT 5
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(3373, 1988, 81, 'Brenda Russell feat. Joe Esposito', 'Brenda Russell', 'Piano In The Dark', 3374.0),
#  (3374, 1988, 81, 'Brenda Russell feat. Joe Esposito', 'Joe Esposito', 'Piano In The Dark', 3375.0),
#  (3521, 1990, 24, 'Glenn Medeiros feat. Bobby Brown', 'Glenn Medeiros', "She Ain't Worth It", 3522.0),
#  (3522, 1990, 24, 'Glenn Medeiros feat. Bobby Brown', 'Bobby Brown', "She Ain't Worth It", 3523.0),
#  (3618, 1991, 20, 'Marky Mark and The Funky Bunch feat. Loleatta Holloway', 'Marky Mark and The Funky Bunch', 'Good Vibrations', 3619.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end WHERE song_name LIKE '%love%' OR song_name LIKE '%Love%' LIMIT 5
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(13, 1956, 14, 'Elvis Presley', 'Elvis Presley', 'I Want You, I Need You, I Love You', 14.0),
#  (14, 1956, 15, 'Elvis Presley', 'Elvis Presley', 'Love Me Tender', 15.0),
#  (25, 1956, 25, 'Fats Domino', 'Fats Domino', "I'm In Love Again", 26.0),
#  (28, 1956, 28, 'Frankie Lymon and The Teenagers', 'Frankie Lymon and The Teenagers', 'Why Do Fools Fall In Love', 29.0),
#  (44, 1956, 44, 'Bing Crosby and Grace Kelly', 'Bing Crosby', 'True Love', 45.0)]

# %%
# %%sql
#
# SELECT * FROM billboard_top_100_year_end
# WHERE year > 1990
# AND UPPER(song_name)
# LIKE UPPER('% me %')
# OR song_name LIKE 'Me %'
# OR song_name LIKE '% Me %'
# OR song_name LIKE '% Me'
# Out:
#  * postgresql+psycopg2://localhost:5432/intro_to_sql_for_analytics
# 320 rows affected.
# [(26, 1956, 26, 'Patience and Prudence', 'Patience and Prudence', 'Tonight You Belong To Me', 27.0),
#  (60, 1956, 59, 'Jerry Vale', 'Jerry Vale', "You Don't Know Me", 61.0),
#  (98, 1956, 96, 'Lawrence Welk', 'Lawrence Welk', 'Tonight You Belong to Me', 99.0),
#  (108, 1957, 6, 'Pat Boone', 'Pat Boone', "Don't Forbid Me", 109.0),
#  (120, 1957, 18, 'Del-Vikings', 'Del-Vikings', 'Come Go With Me', 121.0),
#  (122, 1957, 20, 'Sam Cooke', 'Sam Cooke', 'You Send Me', 123.0),
#  (142, 1957, 40, 'Nat King Cole', 'Nat King Cole', 'Send For Me', 143.0),
#  (158, 1957, 56, 'Elvis Presley', 'Elvis Presley', 'Love Me', 159.0),
#  (212, 1958, 10, 'Dean Martin', 'Dean Martin', 'Return To Me', 213.0),
#  (254, 1958, 51, 'Don Gibson', 'Don Gibson', 'Oh Lonesome Me', 255.0),
#  (311, 1959, 8, 'Fleetwoods', 'Fleetwoods', 'Come Softly To Me', 312.0),
# ...
